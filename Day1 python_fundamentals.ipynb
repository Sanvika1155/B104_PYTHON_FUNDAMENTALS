# %%
print("hello world!")
# Out:
# hello world!

# %%
print("Thank you faiyaz sir")
# Out:
# Thank you faiyaz sir

# %%
print("Welcome")
# Out:
# Welcome

# %%
print("egypt")
# Out:
# egypt

# %%
print("Digital marketing")
# Out:
# Digital marketing

# %%
print("throat")
# Out:
# throat

# %%
print("Learning")
# Out:
# Learning

# %%
print("stories")
# Out:
# stories
