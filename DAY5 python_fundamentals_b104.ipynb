# %%
classmates=['sanvika','srija','pranitha','hemalatha','keerthi']
print(classmates)
# Out:
# ['sanvika', 'srija', 'pranitha', 'hemalatha', 'keerthi']

# %%
print(classmates[2].title())
# Out:
# Pranitha

# %%
del classmates[3]
print(classmates)
# Out:
# ['sanvika', 'srija', 'pranitha', 'keerthi']

# %%
a=classmates.pop()
print(a)
print(classmates)
# Out:
# keerthi
# ['sanvika', 'srija', 'pranitha']

# %%
cars=['audi','altro','benz','bmw','suzuki']
print(cars)
# Out:
# ['audi', 'altro', 'benz', 'bmw', 'suzuki']

# %%
cars.sort()
print(cars)
# Out:
# ['altro', 'audi', 'benz', 'bmw', 'suzuki']

# %%
print(sorted(classmates))
# Out:
# ['pranitha', 'sanvika', 'srija']

# %%
cars.reverse()
print(cars)
# Out:
# ['suzuki', 'bmw', 'benz', 'audi', 'altro']

# %%
fruits=['apple','mango','kiwi','grapes']
print(fruits)
# Out:
# ['apple', 'mango', 'kiwi', 'grapes']

# %%
print(sorted(fruits))
# Out:
# ['apple', 'grapes', 'kiwi', 'mango']

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'grapes', 'kiwi', 'mango']

# %%
del fruits[2]
print(fruits)
# Out:
# ['apple', 'grapes', 'mango']

# %%
d=fruits.
