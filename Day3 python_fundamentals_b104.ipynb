# %%
day3 string methods

# %%
name="raju yadav"
print(name)
# Out:
# raju yadav

# %%
print(name.title())
# Out:
# Raju Yadav

# %%
print(name.upper())
# Out:
# RAJU YADAV

# %%
name1="VACHANA"
print(name1)
# Out:
# VACHANA

# %%
print(name1.lower())
# Out:
# vachana

# %%
a="python programming"
print(a.title())
# Out:
# Python Programming

# %%
print(a.upper())
# Out:
# PYTHON PROGRAMMING

# %%
name2="PYTHON PROGRAMMING"
print(name2.lower())
# Out:
# python programming

# %%
firstname="sanvika"
lastname="bandi"
fullname=f"{firstname}{lastname}"
print(fullname)
# Out:
# sanvikabandi

# %%
print(fullname.title())
# Out:
# Sanvikabandi

# %%
q="vedha"
r="pravasthi"
s=f"{q} {r}"
print(s)
# Out:
# vedha pravasthi

# %%
print(s.title())
# Out:
# Vedha Pravasthi

# %%
print(s.upper())
# Out:
# VEDHA PRAVASTHI

# %%
message=f"Keep up the good work {s}"
print(message)
# Out:
# Keep up the good work vedha pravasthi

# %%
print(message.title())
# Out:
# Keep Up The Good Work Vedha Pravasthi

# %%
print(message.upper())
# Out:
# KEEP UP THE GOOD WORK VEDHA PRAVASTHI

# %%
#white strips#
c="python"
print(c)
# Out:
# python

# %%
d=" programming"
print(d.title())
# Out:
#  Programming

# %%
print(d.lstrip())
# Out:
# programming

# %%
f=" content creator "
print(f.strip())
# Out:
# content creator

# %%
g="youtube recommendations "
print(g)
# Out:
# youtube recommendations

# %%
print(g.rstrip())
# Out:
# youtube recommendations
