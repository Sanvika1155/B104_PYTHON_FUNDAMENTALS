# %%
bsc_honours=['sanvika','anjani','arunjyothi','srija','pooja','navya','laxmi prasanna']
print(bsc_honours)
# Out:
# ['sanvika', 'anjani', 'arunjyothi', 'srija', 'pooja', 'navya', 'laxmi prasanna']

# %%
print(bsc_honours[0:7])
# Out:
# ['sanvika', 'anjani', 'arunjyothi', 'srija', 'pooja', 'navya', 'laxmi prasanna']

# %%
print(bsc_honours[1:7:2])
# Out:
# ['anjani', 'srija', 'navya']

# %%
print(bsc_honours[0:7:2])
# Out:
# ['sanvika', 'arunjyothi', 'pooja', 'laxmi prasanna']

# %%
print(bsc_honours[0:8])
# Out:
# ['sanvika', 'anjani', 'arunjyothi', 'srija', 'pooja', 'navya', 'laxmi prasanna']

# %%
print(bsc_honours[0:7:3])
# Out:
# ['sanvika', 'srija', 'laxmi prasanna']

# %%
print(bsc_honours[0:7:4])
# Out:
# ['sanvika', 'pooja']

# %%
print(bsc_honours[1:7:4])
# Out:
# ['anjani', 'navya']

# %%
print(bsc_honours[0:7:5])
# Out:
# ['sanvika', 'navya']

# %%
print(bsc_honours[0:7:7])
# Out:
# ['sanvika']

# %%
print(f"{bsc_honours[0:7:7].title()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(f"{bsc_honours[0:7:7].title()}")
#
# AttributeError: 'list' object has no attribute 'title'

# %%
#for loop

for i in bsc_honours:
    print(i)
# Out:
# sanvika
# anjani
# arunjyothi
# srija
# pooja
# navya
# laxmi prasanna

# %%
for i in bsc_honours:
    print(f"happy vinayaka chaturthi,{bsc_honours[0].title()}")
# Out:
# happy vinayaka chaturthi,Sanvika
# happy vinayaka chaturthi,Sanvika
# happy vinayaka chaturthi,Sanvika
# happy vinayaka chaturthi,Sanvika
# happy vinayaka chaturthi,Sanvika
# happy vinayaka chaturthi,Sanvika
# happy vinayaka chaturthi,Sanvika

# %%
for j in bsc_honours:
    print(f"Happy vinayaka chaturthi,{j.title()}")
# Out:
# Happy vinayaka chaturthi,Sanvika
# Happy vinayaka chaturthi,Anjani
# Happy vinayaka chaturthi,Arunjyothi
# Happy vinayaka chaturthi,Srija
# Happy vinayaka chaturthi,Pooja
# Happy vinayaka chaturthi,Navya
# Happy vinayaka chaturthi,Laxmi Prasanna

# %%
for i in bsc_honours:
    print(f"happy vinayaka chaturthi,{i[0].title()}")
# Out:
# happy vinayaka chaturthi,S
# happy vinayaka chaturthi,A
# happy vinayaka chaturthi,A
# happy vinayaka chaturthi,S
# happy vinayaka chaturthi,P
# happy vinayaka chaturthi,N
# happy vinayaka chaturthi,L

# %%
for i in bsc_honours:
    print(f"happy vinayaka chaturthi,{i.title()}")
# Out:
# happy vinayaka chaturthi,Sanvika
# happy vinayaka chaturthi,Anjani
# happy vinayaka chaturthi,Arunjyothi
# happy vinayaka chaturthi,Srija
# happy vinayaka chaturthi,Pooja
# happy vinayaka chaturthi,Navya
# happy vinayaka chaturthi,Laxmi Prasanna

# %%
for x in bsc_honours:
    print(f"keep it up!{x.title()}")
    print(f"well done{x.title()}")
# Out:
# keep it up!Sanvika
# well doneSanvika
# keep it up!Anjani
# well doneAnjani
# keep it up!Arunjyothi
# well doneArunjyothi
# keep it up!Srija
# well doneSrija
# keep it up!Pooja
# well donePooja
# keep it up!Navya
# well doneNavya
# keep it up!Laxmi Prasanna
# well doneLaxmi Prasanna

# %%
for x in bsc_honours:
    print(f"keep it up!! {x.title()}")
    print(f"well done {x.title()}\n")
# Out:
# keep it up!! Sanvika
# well done Sanvika
#
# keep it up!! Anjani
# well done Anjani
#
# keep it up!! Arunjyothi
# well done Arunjyothi
#
# keep it up!! Srija
# well done Srija
#
# keep it up!! Pooja
# well done Pooja
#
# keep it up!! Navya
# well done Navya
#
# keep it up!! Laxmi Prasanna
# well done Laxmi Prasanna

# %%
a=int(in
