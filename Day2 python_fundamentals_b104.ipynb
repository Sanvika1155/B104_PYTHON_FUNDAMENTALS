# %%
Day2  python practise ----> variables

# %%
firstname="sanvika"
print(firstname)
# Out:
# sanvika

# %%
first_name1="seetha"
print(first_name1)
# Out:
# seetha

# %%
lang="python"
print(lang)
# Out:
# python

# %%
name1="Welcome"
print(name1)
# Out:
# Welcome

# %%
type(lang)
# Out:
# str

# %%
we="amma"
print(we)
# Out:
# amma

# %%
type(we)
# Out:
# str

# %%
type(name1)
# Out:
# str

# %%
fav_game="cricket"
print(fav_game)
# Out:
# cricket
