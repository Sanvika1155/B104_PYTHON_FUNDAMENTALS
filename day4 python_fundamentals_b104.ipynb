# %%
flowers=['rose', 'jasmine','marigold','tulip','lotus']
print(flowers)
# Out:
# ['rose', 'jasmine', 'marigold', 'tulip', 'lotus']

# %%
print(flowers[1].title())
# Out:
# Jasmine

# %%
flowers.append('hibiscus')

# %%
print(flowers)
# Out:
# ['rose', 'jasmine', 'marigold', 'tulip', 'lotus', 'hibiscus', 'hibiscus']

# %%
flowers.insert(6,'lilly')
print(flowers)
# Out:
# ['rose', 'jasmine', 'marigold', 'tulip', 'lotus', 'hibiscus', 'lilly', 'hibiscus']

# %%
flowers[5]='raflaia'
print(flowers)
# Out:
# ['rose', 'jasmine', 'marigold', 'tulip', 'lotus', 'raflaia', 'lilly', 'hibiscus']

# %%
chocolates=['5star','dairy milk','kitkat']
print(chocolates)
# Out:
# ['5star', 'dairy milk', 'kitkat']

# %%
print(chocolates[1].title())
# Out:
# Dairy Milk

# %%
chocolates.append('milky bar')
print(chocolates)
# Out:
# ['5star', 'dairy milk', 'kitkat', 'milky bar']

# %%
chocolates.insert(2,'perk')
print(chocolates)
# Out:
# ['5star', 'dairy milk', 'perk', 'kitkat', 'milky bar']

# %%
chocolates[2]='munch'
print(chocolates)
# Out:
# ['5star', 'dairy milk', 'munch', 'kitkat', 'milky bar']
